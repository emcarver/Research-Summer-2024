# %%
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import dates as mdates
from matplotlib import ticker

from matplotlib import rc
rc('text', usetex=True)
font = {'family' : 'serif'}
rc('font', **font)

# %%
time_6_2=[]
flux_6_2=[]
err_6_2=[]

with open('datafile_GX_399-4_05-Oct-2022_233GHz_0hours0min2.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_6_2.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_6_2.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_6_2.append(float(rms_err))
                
time_4_2=[]
flux_4_2=[]
err_4_2=[]

with open('datafile_GX_399-4_05-Oct-2022_145GHz_0hours0min2.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_4_2.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_4_2.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_4_2.append(float(rms_err))
                
time_3_2=[]
flux_3_2=[]
err_3_2=[]

with open('datafile_GX_399-4_05-Oct-2022_97GHz_0hours0min2.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_3_2.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_3_2.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_3_2.append(float(rms_err))
                
                
time_3_6=[]
flux_3_6=[]
err_3_6=[]

with open('datafile_GX_399-4_05-Oct-2022_97GHz_0hours0min6.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_3_6.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_3_6.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_3_6.append(float(rms_err))

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_6_2, flux_6_2, err_6_2, marker='.', linestyle='-', label='233GHz', color='darkorange')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)#, loc=3
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2022/10/05 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

plt.savefig('band_6_20221005.pdf', bbox_inches='tight')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_4_2, flux_4_2, err_4_2, marker='.', linestyle='-', label='144.98GHz', color='b')


locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2022/10/05 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

#plt.savefig('band_4_20221005.pdf', bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Flux Density (mJy bm$^{-1}$)')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_3_2, flux_3_2, err_3_2, marker='.', linestyle='-',label='97.49GHz', color='g')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20, loc=3)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2022/10/05 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

#plt.savefig('band_4_20221005.pdf', bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Flux Density (mJy bm$^{-1}$)')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_3_6, flux_3_6, err_3_6, marker='.', linestyle='-',label='97.49GHz', color='g')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20, loc=3)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2022/10/05 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

#plt.savefig('band_4_20221005.pdf', bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Flux Density (mJy bm$^{-1}$)')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_3_2, flux_3_2, err_3_2, marker='.', linestyle='-', label='97.5 GHz', color='g')
ax.errorbar(time_4_2, flux_4_2, err_4_2, marker='.', linestyle='-', label='145 GHz', color='b')
ax.errorbar(time_6_2, flux_6_2, err_6_2, marker='.', linestyle='-', label='233 GHz', color='darkorange')

locator0 = mdates.MinuteLocator(interval=5)
locator1 = mdates.MinuteLocator(interval=1)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=26)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=28, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2022/10/05 (HH:MM)',fontsize=34)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=34)

plt.savefig('light_curves_full_20221005.pdf', bbox_inches='tight')

# %%
time8_6_2=[]
flux8_6_2=[]
err8_6_2=[]

with open('datafile_GX_399-4_08-Oct-2022_233GHz_0hours0min2.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time8_6_2.append(float(MJD))
            if peak_flux != 'err|peak':
                flux8_6_2.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err8_6_2.append(float(rms_err))
                
time8_4_2=[]
flux8_4_2=[]
err8_4_2=[]

with open('datafile_GX_399-4_08-Oct-2022_145GHz_0hours0min2.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time8_4_2.append(float(MJD))
            if peak_flux != 'err|peak':
                flux8_4_2.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err8_4_2.append(float(rms_err))
                
time8_3_2=[]
flux8_3_2=[]
err8_3_2=[]

with open('datafile_GX_399-4_08-Oct-2022_97GHz_0hours0min2.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time8_3_2.append(float(MJD))
            if peak_flux != 'err|peak':
                flux8_3_2.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err8_3_2.append(float(rms_err))

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time8_6_2, flux8_6_2, err8_6_2, marker='.', linestyle='-', label='232.97GHz', color='darkorange')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)#, loc=3
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2022/10/08 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

#plt.savefig('band_6_20221008.pdf', bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Flux Density (mJy bm$^{-1}$)')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time8_4_2, flux8_4_2, err8_4_2, marker='.', linestyle='-', label='144.98GHz', color='b')


locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2022/10/08 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

#plt.savefig('band_4_20221008.pdf', bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Flux Density (mJy bm$^{-1}$)')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time8_3_2, flux8_3_2, err8_3_2, marker='.', linestyle='-',label='97.49GHz', color='g')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20, loc=3)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2022/10/08 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

#plt.savefig('band_4_20221008.pdf', bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Flux Density (mJy bm$^{-1}$)')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time8_3_2, flux8_3_2, err8_3_2, marker='.', linestyle='-', label='97.5 GHz', color='g')
ax.errorbar(time8_4_2, flux8_4_2, err8_4_2, marker='.', linestyle='-', label='145 GHz', color='b')
ax.errorbar(time8_6_2, flux8_6_2, err8_6_2, marker='.', linestyle='-', label='233 GHz', color='darkorange')

locator0 = mdates.MinuteLocator(interval=5)
locator1 = mdates.MinuteLocator(interval=1)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=26)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=28, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2022/10/08 (HH:MM)',fontsize=34)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=34)

plt.savefig('light_curves_full_20221008.pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(16,5))


ax[0].errorbar(time8_3_2, flux8_3_2, err8_3_2, marker='.', linestyle='-', label='97.49GHz', color='g')
ax[1].errorbar(time8_4_2, flux8_4_2, err8_4_2, marker='.', linestyle='-', label='144.98GHz', color='b')
ax[2].errorbar(time8_6_2, flux8_6_2, err8_6_2, marker='.', linestyle='-', label='232.97GHz', color='darkorange')


locator0 = mdates.MinuteLocator(interval=1)
locator1 = mdates.SecondLocator(interval=30)
for n in range(3):
    ax[n].xaxis.set_major_locator(locator0)
    ax[n].xaxis.set_minor_locator(locator1)
    ax[n].legend(fontsize=16)
    ax[n].xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
    #plt.setp(ax[n].get_xticklabels(), rotation=45, horizontalalignment='right')
    ax[n].tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
    ax[n].tick_params(axis='y', which='both', left='on', right='on', direction='in') 
    ax[n].tick_params(axis='both', which='minor', length=5, width=0.8)
    ax[n].tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
    ax[n].yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax[1].set_xlabel('Time on 2022/10/08 (HH:MM)',fontsize=14)
ax[0].set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=16)

#plt.savefig('w.pdf', bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Flux Density (mJy bm$^{-1}$)')

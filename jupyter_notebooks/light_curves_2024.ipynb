# %%
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import dates as mdates
from matplotlib import ticker

# %%
time_3_30=[]
flux_3_30=[]
err_3_30=[]

with open('datafile_GX339-4_10-Mar-2024_97.48916GHz_0hours0min30.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_3_30.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_3_30.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_3_30.append(float(rms_err))

# %%
time_3_25=[]
flux_3_25=[]
err_3_25=[]

with open('datafile_GX339-4_10-Mar-2024_97.48916GHz_0hours0min25.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_3_25.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_3_25.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_3_25.append(float(rms_err))

# %%
time_3_20=[]
flux_3_20=[]
err_3_20=[]

with open('datafile_GX339-4_10-Mar-2024_97.48916GHz_0hours0min20.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_3_20.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_3_20.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_3_20.append(float(rms_err))

# %%
time_3_15=[]
flux_3_15=[]
err_3_15=[]

with open('datafile_GX339-4_10-Mar-2024_97.48916GHz_0hours0min15.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_3_15.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_3_15.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_3_15.append(float(rms_err))

# %%
time_3_12=[]
flux_3_12=[]
err_3_12=[]

with open('datafile_GX339-4_10-Mar-2024_97.48916GHz_0hours0min12.5sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_3_12.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_3_12.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_3_12.append(float(rms_err))

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_3_30, flux_3_30, err_3_30, marker='o', linestyle='-',label='97.49GHz', color='g')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2024/03/10 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

plt.savefig('746_30s.pdf')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_3_25, flux_3_25, err_3_25, marker='o', linestyle='-',label='97.49GHz', color='g')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2024/03/10 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

plt.savefig('746_25s.pdf')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_3_20, flux_3_20, err_3_20, marker='o', linestyle='-',label='97.49GHz', color='g')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2024/03/10 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

plt.savefig('746_20s.pdf')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_3_15, flux_3_15, err_3_15, marker='o', linestyle='-',label='97.49GHz', color='g')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20, loc=3)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2024/03/10 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

plt.savefig('746_15s.pdf')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_3_12, flux_3_12, err_3_12, marker='o', linestyle='-',label='97.49GHz', color='g')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20, loc=3)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2024/03/10 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

plt.savefig('746_12.5s.pdf')

# %%
time_4_60=[]
flux_4_60=[]
err_4_60=[]

with open('datafile_GX339-4_10-Mar-2024_144.9839GHz_0hours1min0.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_4_60.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_4_60.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_4_60.append(float(rms_err))

# %%
time_4_50=[]
flux_4_50=[]
err_4_50=[]

with open('datafile_GX339-4_10-Mar-2024_144.9839GHz_0hours0min50.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_4_50.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_4_50.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_4_50.append(float(rms_err))

# %%
time_4_45=[]
flux_4_45=[]
err_4_45=[]

with open('datafile_GX339-4_10-Mar-2024_144.9839GHz_0hours0min45.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_4_45.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_4_45.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_4_45.append(float(rms_err))

# %%
time_4_40=[]
flux_4_40=[]
err_4_40=[]

with open('datafile_GX339-4_10-Mar-2024_144.9839GHz_0hours0min40.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_4_40.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_4_40.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_4_40.append(float(rms_err))

# %%
time_4_35=[]
flux_4_35=[]
err_4_35=[]

with open('datafile_GX339-4_10-Mar-2024_144.9839GHz_0hours0min35.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_4_35.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_4_35.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_4_35.append(float(rms_err))

# %%
time_4_30=[]
flux_4_30=[]
err_4_30=[]

with open('datafile_GX339-4_10-Mar-2024_144.9839GHz_0hours0min30.0sec.txt') as file:
        for line in file:
            space_one=line.find(' ')
            space_two=line.find(' ', space_one+1)
            space_three=line.find(' ', space_two+1)
            space_four=line.find(' ', space_three+1)
            space_five=line.find(' ', space_four+1)
            line_break=line.find('\n', space_five)

            MJD=line[0:space_one]
            int_flux=line[space_one+1:space_two]
            int_err=line[space_two+1:space_three]
            peak_flux=line[space_three+1:space_four]
            peak_err=line[space_four+1:space_five]
            rms_err=line[space_five+1:line_break]

            if MJD != '#MJD|integ':
                time_4_30.append(float(MJD))
            if peak_flux != 'err|peak':
                flux_4_30.append(float(peak_flux))
            if rms_err != 'imfit err|rms error':
                err_4_30.append(float(rms_err))

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_4_60, flux_4_60, err_4_60, marker='o', linestyle='-', label='144.98GHz', color='b')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2024/03/10 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

plt.savefig('7cc_60s.pdf')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_4_50, flux_4_50, err_4_50, marker='o', linestyle='-', label='144.98GHz', color='b')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2024/03/10 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

plt.savefig('7cc_50s.pdf')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_4_45, flux_4_45, err_4_45, marker='o', linestyle='-', label='144.98GHz', color='b')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2024/03/10 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

plt.savefig('7cc_45s.pdf')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_4_40, flux_4_40, err_4_40, marker='o', linestyle='-', label='144.98GHz', color='b')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2024/03/10 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

plt.savefig('7cc_40s.pdf')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_4_35, flux_4_35, err_4_35, marker='o', linestyle='-', label='144.98GHz', color='b')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2024/03/10 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

plt.savefig('7cc_35s.pdf')

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(111)

ax.errorbar(time_4_30, flux_4_30, err_4_30, marker='o', linestyle='-', label='144.98GHz', color='b')

locator0 = mdates.SecondLocator(interval=60)
locator1 = mdates.SecondLocator(interval=30)
ax.xaxis.set_major_locator(locator0)
ax.xaxis.set_minor_locator(locator1)
ax.legend(fontsize=20)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.tick_params(axis='x', which='both', top='on', bottom='on', direction='in', labelbottom=True)
ax.tick_params(axis='y', which='both', left='on', right='on', direction='in') 
ax.tick_params(axis='both', which='minor', length=5, width=0.8)
ax.tick_params(axis='both', which='major', labelsize=18, length=8, width=1)
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(5))

ax.set_xlabel('Time on 2024/03/10 (HH:MM)',fontsize=22)
ax.set_ylabel('Flux Density (mJy bm$^{-1}$)',fontsize=22)

plt.savefig('7cc_30s.pdf')
